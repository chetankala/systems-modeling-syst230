# %% [markdown]
# # Submission Guidelines:
# ---
#
# 1. Homework Guidelines: **Please start your work early as it takes time to understand and debug programs.** Homework assignments cannot be completed in a single sitting.
#
# 2. Homework Deadlines:  You need to complete your work on time. **No extensions** will be given for this assignment.
#
# 3. Homework Work Package: Please keep all your **notebooks and data in a single directory** and follow the **naming convention Project-XX_First_Last.zip**
#
# 4. Solution Notebooks: Submit your solutions as **Juypter Notebooks**.  Please use this note book as a template. You can **add cells and code** to this note book as needed.
#
# 5. Naming File: Name the solution file as **First_Last_Group#_Project#.ipynb** where First and Last is your first and last name and Group# is your group Number.
#
# 6. Test Cases: Please add other test cases as you see fit to demonstrate that your code and functions work.

# %% [markdown]
# ## Please Update
# ---
#
# Member-1: First Name, Last Name, G#
#
# Member-2: First Name, Last Name, G#
#
# **Honor Code**:
# We certify that:
#
#     1. This assignment is our work.
#     2. We have not taken help from any other individuals or resources while doing this assignment
#     3. Each member of the team has worked on all parts of the assignment and understand the code that is submitted as a solution.

# %% [markdown]
# ## Question 1: [100 Points]
# ---
# In this question, you would be doing some data analysis using the Pandas package. You can refer to Pandas documentation and online help in case you need to look up function syntax.

# %% [markdown]
# ## Background:
# ---
# Bike-sharing systems are a new generation of traditional bike rentals where the whole process from membership, rental, and return has become automatic. Through these systems, the user can easily rent a bike from a particular position and return to another place. There are about over 500 bike-sharing programs around the world, composed of over 500 thousand bicycles. Today, there is a great interest in these systems due to their traffic, environmental, and health impacts.
# Apart from interesting real-world applications of bike sharing systems, these systems' characteristics are generated by these systems make them attractive for the research. As opposed to other transport services such as bus or subway, the duration of travel, departure, and arrival position is explicitly recorded in these systems. This feature turns the bike-sharing system into a virtual sensor network that can be used to sense mobility in the city. Hence, it is expected that most of important events in the city could be detected via monitoring these data.

# %% [markdown]
# ## Data Description:
# ---
#
# - instant: record index
# - dteday : date
# - season : season (1:springer, 2:summer, 3:fall, 4:winter)
# - yr : year (0: 2011, 1:2012)
# - mnth : month ( 1 to 12)
# - hr : hour (0 to 23)
# - holiday : weather day is holiday or not
# - weekday : day of the week
# - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# + weathersit :
# 		- 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 		- 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 		- 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 		- 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
#
# - temp : Normalized temperature in Celsius. The values are divided to 41 (max)
# - atemp: Normalized feeling temperature in Celsius. The values are divided to 50 (max)
# - hum: Normalized humidity. The values are divided to 100 (max)
# - windspeed: Normalized wind speed. The values are divided to 67(max)
# - casual: count of casual users
# - registered: count of registered users
# - cnt: count of total rental bikes including both casual and registered

# %% [markdown]
# ## Part 1:
# ---
# Load the dataset in a Pandas DataFrame. Describe the types of the column, size, shape, and descriptive statistics for this DataFrame.

# %%
### Note: Please write your code in this cell.
import pandas as pd

df = pd.read_csv("bike_share_data.csv")
df = pd.DataFrame(df)
df.describe()
# Out:
#        Unnamed: 0     instant        season            yr          mnth  \
# count  17379.0000  17379.0000  17379.000000  17379.000000  17379.000000
# mean    8689.0000   8690.0000      2.501640      0.502561      6.537775
# std     5017.0295   5017.0295      1.106918      0.500008      3.438776
# min        0.0000      1.0000      1.000000      0.000000      1.000000
# 25%     4344.5000   4345.5000      2.000000      0.000000      4.000000
# 50%     8689.0000   8690.0000      3.000000      1.000000      7.000000
# 75%    13033.5000  13034.5000      3.000000      1.000000     10.000000
# max    17378.0000  17379.0000      4.000000      1.000000     12.000000
#
#                  hr       holiday       weekday    workingday    weathersit  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean      11.546752      0.028770      3.003683      0.682721      1.425283
# std        6.914405      0.167165      2.005771      0.465431      0.639357
# ...

# %% [markdown]
# ## Part 2:
# ---
# Column Descriptions:
#
# a.	The "seasons" column contains values from 1 to 4, which encode respectively Winter, Spring, Summer, and Fall season.
#
# b.	The "year" column contains the values 0 and 1 represents 2011 and 2012.
#
# c.	The 'weekdays' column contains values from 0 to 6, each one representing a day of the week (0: Sunday, 1: Monday, …, 6: Saturday).
#
# d.	The "weathersit" column represents the current weather conditions, "1" stands for clear weather with few clouds, "2" represents cloudy weather, "3" relates to light snow or rain, and "4" stands for heavy snow or rain.
#
# e.	The "hum" column stands for the current normalized air humidity, with values from 0 to 1 (hence we will multiply the column's values by 100 to obtain percentages).
#
# f.	The 'windspeed' column represents the windspeed, again normalized from values between 0 and 67 m/s.

# %% [markdown]
# ## Part 3:
# ---
# Write a function that checks that the casual plus registered rides are equal to each row's total ride count in the dataset.

# %%
### Note: Please write your code in this cell.
def count_check(data):
    for index, row in data.iterrows():
        if row['casual'] + row['registered'] == row['cnt']:
            continue
        else: 
            print("Not every row is equal")
            return
    print("Every row is equal")
        
count_check(df)
# Out:
# Every row is equal

# %% [markdown]
# ## Part 4:
# ---
# Write four functions to transform the dataset for a more human-readable format:
# - seasons_map
# - year_map
# - weekdays_map
# - weathersit_map
#
# The mapping should be as described below:
#
# a.	Seasons = {1: 'winter', 2: 'spring', 3: 'summer', 4: 'fall'}
#
# b.	Year = {0: 2011, 1: 2012}
#
# c.	Weekdays = {0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday'}
#
# d.	Weathersit = {1: 'clear', 2: 'cloudy', 3: 'light_rain_snow', 4: 'heavy_rain_snow'}

# %%
### Note: Please write your function (seasons_map) in this cell.
def seasons_map(df):
    season = {1: 'winter', 2: 'spring', 3: 'summer', 4: 'fall'}
    df['season'] = df['season'].map(season, na_action=None)
    #print(df)
    
seasons_map(df)

# %%
### Note: Please write your function (year_map) in this cell.
def year_map(df):
    year = {0:2011, 1:2012}
    df['yr'] = df['yr'].map(year, na_action=None)
    #print(df)

year_map(df)

# %%
### Note: Please write your function (weekdays_map) in this cell.
def weekdays_map(df):
    weekdays = {0: 'Sunday', 1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday',
                5: 'Friday', 6: 'Saturday'}
    df['weekday'] = df['weekday'].map(weekdays, na_action=None)
    #print(df)

weekdays_map(df)

# %%
### Note: Please write your function (weathersit_map) in this cell.
def weathersit_map(df):
    weathersit = {1: 'clear', 2: 'cloudy', 3: 'light_rain_snow', 4: 'heavy_rain_snow'}
    df['weathersit'] = df['weathersit'].map(weathersit, na_action=None)
    #print(df)

weathersit_map(df)

# %% [markdown]
# ## Part 5:
# ---
# Transform the dataset into a human-readable format using the mapping functions developed above.

# %%
### Note: Please write your code in this cell.
print(df)
# Out:
#        Unnamed: 0  instant      dteday  season    yr  mnth  hr  holiday  \
# 0               0        1  2011-01-01  winter  2011     1   0        0
# 1               1        2  2011-01-01  winter  2011     1   1        0
# 2               2        3  2011-01-01  winter  2011     1   2        0
# 3               3        4  2011-01-01  winter  2011     1   3        0
# 4               4        5  2011-01-01  winter  2011     1   4        0
# ...           ...      ...         ...     ...   ...   ...  ..      ...
# 17374       17374    17375  2012-12-31  winter  2012    12  19        0
# 17375       17375    17376  2012-12-31  winter  2012    12  20        0
# 17376       17376    17377  2012-12-31  winter  2012    12  21        0
# 17377       17377    17378  2012-12-31  winter  2012    12  22        0
# 17378       17378    17379  2012-12-31  winter  2012    12  23        0
#
#         weekday  workingday weathersit  temp   atemp   hum  windspeed  casual  \
# ...

# %% [markdown]
# ## Part 6:
# ---
# Sample 5 records at random from this dataset to show that you have transformed it correctly.

# %%
### Note: Please write your code in this cell.
df.sample(5)
# Out:
#        Unnamed: 0  instant      dteday  season    yr  mnth  hr  holiday  \
# 15355       15355    15356  2012-10-07    fall  2012    10   0        0
# 14579       14579    14580  2012-09-04  summer  2012     9  16        0
# 16669       16669    16670  2012-12-02    fall  2012    12   8        0
# 3117         3117     3118  2011-05-14  spring  2011     5  19        0
# 1082         1082     1083  2011-02-17  winter  2011     2  20        0
#
#         weekday  workingday       weathersit  temp   atemp   hum  windspeed  \
# 15355    Sunday           0            clear  0.44  0.4394  0.62     0.1642
# 14579   Tuesday           1            clear  0.76  0.7273  0.70     0.4179
# 16669    Sunday           0           cloudy  0.26  0.2879  0.93     0.0896
# 3117   Saturday           0  light_rain_snow  0.54  0.5152  0.94     0.1343
# 1082   Thursday           1            clear  0.48  0.4697  0.59     0.3284
#
#        casual  registered  cnt
# 15355      28          99  127
# ...

# %% [markdown]
# ## Part 7:
# ---
# Count the number of clear, cloudy, and snow days by season.

# %%
### Note: Please write your code in this cell.
import pandas as pd

df = pd.read_csv("bike_share_data.csv")
df = pd.DataFrame(df)
    

x1=df.loc[df['season'] == 1]
x2=df.loc[df['season'] == 2]
x3=df.loc[df['season'] == 3]
x4=df.loc[df['season'] == 4]

clear1=0
cloudy1=0
low_rain_snow1=0
hi_rain_snow1=0

clear2=0
cloudy2=0
low_rain_snow2=0
hi_rain_snow2=0

clear3=0
cloudy3=0
low_rain_snow3=0
hi_rain_snow3=0

clear4=0
cloudy4=0
low_rain_snow4=0
hi_rain_snow4=0

for w in x1['weathersit']:
    if w==1:
        clear1+=1
    elif w==2:
        cloudy1+=1
    elif w==3:
        low_rain_snow1+=1
    elif w==4:
        hi_rain_snow1+=1
        
for w in x2['weathersit']:
    if w==1:
        clear2+=1
    elif w==2:
        cloudy2+=1
    elif w==3:
        low_rain_snow2+=1
    elif w==4:
        hi_rain_snow2+=1
        
for w in x3['weathersit']:
    if w==1:
        clear3+=1
    elif w==2:
        cloudy3+=1
    elif w==3:
        low_rain_snow3+=1
    elif w==4:
        hi_rain_snow3+=1
        
for w in x4['weathersit']:
    if w==1:
        clear4+=1
    elif w==2:
        cloudy4+=1
    elif w==3:
        low_rain_snow4+=1
    elif w==4:
        hi_rain_snow4+=1
        
print('In Winter there were:')
print(str(int(clear1/24)) + ' clear days.')
print(str(int(cloudy1/24)) + ' cloudy days.')
print(str(int(low_rain_snow1/24)) + ' days with light snow/rain.')
print(str(int(hi_rain_snow1/24)) + ' days with heavy snow/rain.')
print()
print('In Spring there were:')
print(str(int(clear2/24)) + ' clear days.')
print(str(int(cloudy2/24)) + ' cloudy days.')
print(str(int(low_rain_snow2/24)) + ' days with light snow/rain.')
print(str(int(hi_rain_snow2/24)) + ' days with heavy snow/rain.')
print()
print('In Summer there were:')
print(str(int(clear3/24)) + ' clear days.')
print(str(int(cloudy3/24)) + ' cloudy days.')
print(str(int(low_rain_snow3/24)) + ' days with light snow/rain.')
print(str(int(hi_rain_snow3/24)) + ' days with heavy snow/rain.')
print()
print('In Fall there were:')
print(str(int(clear4/24)) + ' clear days.')
print(str(int(cloudy4/24)) + ' cloudy days.')
print(str(int(low_rain_snow4/24)) + ' days with light snow/rain.')
print(str(int(hi_rain_snow4/24)) + ' days with heavy snow/rain.')
print()
# Out:
# In Winter there were:
# 111 clear days.
# 50 cloudy days.
# 15 days with light snow/rain.
# 0 days with heavy snow/rain.
#
# In Spring there were:
# 119 clear days.
# 47 cloudy days.
# 16 days with light snow/rain.
# 0 days with heavy snow/rain.
#
# In Summer there were:
# 136 clear days.
# 39 cloudy days.
# 11 days with light snow/rain.
# 0 days with heavy snow/rain.
#
# In Fall there were:
# 108 clear days.
# 52 cloudy days.
# 15 days with light snow/rain.
# 0 days with heavy snow/rain.

# %% [markdown]
# ## Part 8:
# ---
# Which month has the most cloudy days?

# %%
### Note: Please write your code in this cell.
df = pd.read_csv("bike_share_data.csv")
df = pd.DataFrame(df)

m1 = df.loc[df['mnth'] == 1]
m2 = df.loc[df['mnth'] == 2]
m3 = df.loc[df['mnth'] == 3]
m4 = df.loc[df['mnth'] == 4]
m5 = df.loc[df['mnth'] == 5]
m6 = df.loc[df['mnth'] == 6]
m7 = df.loc[df['mnth'] == 7]
m8 = df.loc[df['mnth'] == 8]
m9 = df.loc[df['mnth'] == 9]
m10 = df.loc[df['mnth'] == 10]
m11 = df.loc[df['mnth'] == 11]
m12 = df.loc[df['mnth'] == 12]

l=[]
l1=[]
count=0

for w in m1['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m2['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m3['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m4['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m5['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m6['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m7['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m8['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m9['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m10['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m11['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for w in m12['weathersit']:
    l1.append(w)
l.append(l1.count(2))
l1=[]

for i in range(len(l)):
    l[i]=int(l[i]/24)

a=l.index(max(l))

print("Month "+str(a+1)+" has the most cloudy days.")
# Out:
# Month 12 has the most cloudy days.

# %% [markdown]
# ## Part 9:
# ---
# Which months have the most  'light_rain_snow',  'heavy_rain_snow' days in this dataset?

# %%
### Note: Please write your code in this cell.
import pandas as pd

df = pd.read_csv("bike_share_data.csv")
df = pd.DataFrame(df)

m1 = df.loc[df['mnth'] == 1]
m2 = df.loc[df['mnth'] == 2]
m3 = df.loc[df['mnth'] == 3]
m4 = df.loc[df['mnth'] == 4]
m5 = df.loc[df['mnth'] == 5]
m6 = df.loc[df['mnth'] == 6]
m7 = df.loc[df['mnth'] == 7]
m8 = df.loc[df['mnth'] == 8]
m9 = df.loc[df['mnth'] == 9]
m10 = df.loc[df['mnth'] == 10]
m11 = df.loc[df['mnth'] == 11]
m12 = df.loc[df['mnth'] == 12]

l3=[]
l4=[]
l=[]
count=0

for w in m1['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m2['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m3['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m4['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m5['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m6['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m7['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m8['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m9['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m10['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m11['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

for w in m12['weathersit']:
    l.append(w)
l3.append(l.count(3))
l4.append(l.count(4))
l=[]

type4=l4.copy()

for i in range(len(l3)):
    l3[i]=int(l3[i]/24)
    
for i in range(len(l4)):
    l4[i]=int(l4[i]/24)

m = max(l3)
n=[i for i, j in enumerate(l3) if j == m]

a=type4.index(max(type4))
print("Month "+str(a+1)+" had " +str(max(type4))+ " hours of heavy snow/rain")

print("Months "+str(n[0])+ ' and '+ str(n[1])+" have the most days with light snow/rain.")
# Out:
# Month 1 had 3 hours of heavy snow/rain
# Months 8 and 9 have the most days with light snow/rain.

# %% [markdown]
# ## Part 10:
# ---
# Draw a histogram of rides by day of the week for all the months in the dataset.

# %%
### Note: Please write your code in this cell.
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("bike_share_data.csv")
df = pd.DataFrame(df)

x=['Jan','Feb','Mar','Apr','May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
y0=[]
y1=[]
y2=[]
y3=[]
y4=[]
y5=[]
y6=[]

l=[]

m1 = df.loc[df['mnth'] == 1]
m2 = df.loc[df['mnth'] == 2]
m3 = df.loc[df['mnth'] == 3]
m4 = df.loc[df['mnth'] == 4]
m5 = df.loc[df['mnth'] == 5]
m6 = df.loc[df['mnth'] == 6]
m7 = df.loc[df['mnth'] == 7]
m8 = df.loc[df['mnth'] == 8]
m9 = df.loc[df['mnth'] == 9]
m10 = df.loc[df['mnth'] == 10]
m11 = df.loc[df['mnth'] == 11]
m12 = df.loc[df['mnth'] == 12]

jan0 = m1.loc[m1['weekday'] == 0]
jan1 = m1.loc[m1['weekday'] == 1]
jan2 = m1.loc[m1['weekday'] == 2]
jan3 = m1.loc[m1['weekday'] == 3]
jan4 = m1.loc[m1['weekday'] == 4]
jan5 = m1.loc[m1['weekday'] == 5]
jan6 = m1.loc[m1['weekday'] == 6]

for w in jan0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in jan1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in jan2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in jan3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in jan4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in jan5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in jan6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]


feb0 = m2.loc[m2['weekday'] == 0]
feb1 = m2.loc[m2['weekday'] == 1]
feb2 = m2.loc[m2['weekday'] == 2]
feb3 = m2.loc[m2['weekday'] == 3]
feb4 = m2.loc[m2['weekday'] == 4]
feb5 = m2.loc[m2['weekday'] == 5]
feb6 = m2.loc[m2['weekday'] == 6]

for w in feb0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in feb1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in feb2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in feb3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in feb4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in feb5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in feb6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]


mar0 = m3.loc[m3['weekday'] == 0]
mar1 = m3.loc[m3['weekday'] == 1]
mar2 = m3.loc[m3['weekday'] == 2]
mar3 = m3.loc[m3['weekday'] == 3]
mar4 = m3.loc[m3['weekday'] == 4]
mar5 = m3.loc[m3['weekday'] == 5]
mar6 = m3.loc[m3['weekday'] == 6]

for w in mar0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in mar1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in mar2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in mar3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in mar4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in mar5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in mar6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]

apr0 = m4.loc[m4['weekday'] == 0]
apr1 = m4.loc[m4['weekday'] == 1]
apr2 = m4.loc[m4['weekday'] == 2]
apr3 = m4.loc[m4['weekday'] == 3]
apr4 = m4.loc[m4['weekday'] == 4]
apr5 = m4.loc[m4['weekday'] == 5]
apr6 = m4.loc[m4['weekday'] == 6]

for w in apr0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in apr1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in apr2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in apr3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in apr4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in apr5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in apr6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]

may0 = m5.loc[m5['weekday'] == 0]
may1 = m5.loc[m5['weekday'] == 1]
may2 = m5.loc[m5['weekday'] == 2]
may3 = m5.loc[m5['weekday'] == 3]
may4 = m5.loc[m5['weekday'] == 4]
may5 = m5.loc[m5['weekday'] == 5]
may6 = m5.loc[m5['weekday'] == 6]

for w in may0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in may1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in may2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in may3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in may4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in may5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in may6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]

jun0 = m6.loc[m6['weekday'] == 0]
jun1 = m6.loc[m6['weekday'] == 1]
jun2 = m6.loc[m6['weekday'] == 2]
jun3 = m6.loc[m6['weekday'] == 3]
jun4 = m6.loc[m6['weekday'] == 4]
jun5 = m6.loc[m6['weekday'] == 5]
jun6 = m6.loc[m6['weekday'] == 6]

for w in jun0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in jun1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in jun2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in jun3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in jun4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in jun5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in jun6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]

jul0 = m7.loc[m7['weekday'] == 0]
jul1 = m7.loc[m7['weekday'] == 1]
jul2 = m7.loc[m7['weekday'] == 2]
jul3 = m7.loc[m7['weekday'] == 3]
jul4 = m7.loc[m7['weekday'] == 4]
jul5 = m7.loc[m7['weekday'] == 5]
jul6 = m7.loc[m7['weekday'] == 6]

for w in jul0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in jul1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in jul2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in jul3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in jul4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in jul5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in jul6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]

aug0 = m8.loc[m8['weekday'] == 0]
aug1 = m8.loc[m8['weekday'] == 1]
aug2 = m8.loc[m8['weekday'] == 2]
aug3 = m8.loc[m8['weekday'] == 3]
aug4 = m8.loc[m8['weekday'] == 4]
aug5 = m8.loc[m8['weekday'] == 5]
aug6 = m8.loc[m8['weekday'] == 6]

for w in aug0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in aug1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in aug2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in aug3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in aug4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in aug5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in aug6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]

sep0 = m9.loc[m9['weekday'] == 0]
sep1 = m9.loc[m9['weekday'] == 1]
sep2 = m9.loc[m9['weekday'] == 2]
sep3 = m9.loc[m9['weekday'] == 3]
sep4 = m9.loc[m9['weekday'] == 4]
sep5 = m9.loc[m9['weekday'] == 5]
sep6 = m9.loc[m9['weekday'] == 6]

for w in sep0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in sep1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in sep2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in sep3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in sep4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in sep5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in sep6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]

oct0 = m10.loc[m10['weekday'] == 0]
oct1 = m10.loc[m10['weekday'] == 1]
oct2 = m10.loc[m10['weekday'] == 2]
oct3 = m10.loc[m10['weekday'] == 3]
oct4 = m10.loc[m10['weekday'] == 4]
oct5 = m10.loc[m10['weekday'] == 5]
oct6 = m10.loc[m10['weekday'] == 6]

for w in oct0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in oct1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in oct2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in oct3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in oct4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in oct5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in oct6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]

nov0 = m11.loc[m11['weekday'] == 0]
nov1 = m11.loc[m11['weekday'] == 1]
nov2 = m11.loc[m11['weekday'] == 2]
nov3 = m11.loc[m11['weekday'] == 3]
nov4 = m11.loc[m11['weekday'] == 4]
nov5 = m11.loc[m11['weekday'] == 5]
nov6 = m11.loc[m11['weekday'] == 6]

for w in nov0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in nov1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in nov2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in nov3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in nov4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in nov5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in nov6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]

dec0 = m12.loc[m12['weekday'] == 0]
dec1 = m12.loc[m12['weekday'] == 1]
dec2 = m12.loc[m12['weekday'] == 2]
dec3 = m12.loc[m12['weekday'] == 3]
dec4 = m12.loc[m12['weekday'] == 4]
dec5 = m12.loc[m12['weekday'] == 5]
dec6 = m12.loc[m12['weekday'] == 6]

for w in dec0['cnt']:
    l.append(w)
total = sum(l)
y0.append(total)
l=[]

for w in dec1['cnt']:
    l.append(w)
total = sum(l)
y1.append(total)
l=[]

for w in dec2['cnt']:
    l.append(w)
total = sum(l)
y2.append(total)
l=[]

for w in dec3['cnt']:
    l.append(w)
total = sum(l)
y3.append(total)
l=[]

for w in dec4['cnt']:
    l.append(w)
total = sum(l)
y4.append(total)
l=[]

for w in dec5['cnt']:
    l.append(w)
total = sum(l)
y5.append(total)
l=[]

for w in dec6['cnt']:
    l.append(w)
total = sum(l)
y6.append(total)
l=[]

plt.bar(x,y0,color='red',width=0.5, align="center",label='Sunday')
plt.bar(x,y1,color='orange',bottom=y0,width=0.5, align="center",label='Monday')
plt.bar(x,y2,color='yellow',bottom=y1, width=0.5, align="center",label='Tuesday')
plt.bar(x,y3,color='green',bottom=y2, width=0.5, align="center",label='Wednesday')
plt.bar(x,y4,color='cyan',bottom=y3,width=0.5, align="center",label='Thursday')
plt.bar(x,y5,color='blue',bottom=y4,width=0.5, align="center",label='Friday')
plt.bar(x,y6,color='purple',bottom=y5,width=0.5, align="center",label='Saturday')

plt.xlabel("Months")
plt.ylabel("Number of Rides")
title='Number of Rides Per Weekday Per Month'
plt.title(title)
plt.legend()
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ## ## Question 2: Extra Credit [15 Points]
# ---
# Consider the dataset found at bit.ly which contains movie ratings. You will use this dataset to answer the following questions. It is possible to read the dataset directly into a pandas DataFrame using the following code. You don't need to download it locally. Ensure that you can access the dataset before you start this question by listing the first few lines using the head function.

# %%
import pandas as pd
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head(10)
# Out:
#                    City Colors Reported Shape Reported State              Time
# 0                Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ   6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS    6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY   4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND   9/15/1934 15:30
# 6           Crater Lake             NaN         CIRCLE    CA    6/15/1935 0:00
# 7                  Alma             NaN           DISK    MI    7/15/1936 0:00
# 8               Eklutna             NaN          CIGAR    AK  10/15/1936 17:00
# 9               Hubbard             NaN       CYLINDER    OR    6/15/1937 0:00

# %% [markdown]
# **Dataset**: http://bit.ly/uforeports
#
# **Note**:
# Use the command **ufo.fillna('', inplace=True)** to replace NaN values with blank strings so you are working with strings.
#
# Please get this dataset and use it to answer the following questions.

# %% [markdown]
# ## Part 1:
# ---
# Write a pandas script that read this data in a dataframe and shows the top 10 states with the most number of UFO sightings.

# %%
### Note: Please write your code in this cell.

# %% [markdown]
# ## Part 2:
# ---
# Draw a bar graph that shows the 5 most reported shapes for the UFO!

# %%
### Note: Please write your code in this cell.

# %% [markdown]
# ## Part 3:
# ---
# Draw a bar graph that shows the 5 most reported colors for the UFO in the state of California.

# %%
### Note: Please write your code in this cell.

# %% [markdown]
# ## Part 4:
# ---
# Write a script that converts the ufo dataset into a JSON file and saves it as a file using the Pandas library.

# %%
### Note: Please write your code in this cell.

# %% [markdown]
# ## Part 5:
# ---
# Write  a script that read the saved JSON format file into a dataframe and shows the head, tail and shape of the dataframe.

# %%
### Note: Please write your code in this cell.
